# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
color_list =["#3eb991","#e9a820","#e01563","#edb196","#6ecadc","#1f94ac","#ae9a6a","#ccb8a6","#343a44"]

# %% [markdown]
# # Graphing Definition

# %%
def graph_df(data_frame:pd.DataFrame,begin_index=0,end_index=None):
    if end_index:
        column_name =list(data_frame.columns )[begin_index:end_index]
    else:
        column_name =list(data_frame.columns )[begin_index:]
    fig, ax = plt.subplots()
    print(column_name)
    x = np.arange(0, len(data_frame), step=1)
    

    for i in range(len(column_name)):
        label = column_name[i]
        #ax.scatter(x,test_output[label],color = color_list[i])
        ax.plot(x,data_frame[label],color = color_list[i])
        
    colorlist = zip(column_name,color_list)
    handles = [mpatches.Patch(color=colour, label=column_name) for label, colour in colorlist]
    t = ",".join(column_name)
    plt.legend(handles, column_name, ncol=1, bbox_to_anchor=(1, 1))
    plt.plot()
    plt.xlabel('time (ms)')
    plt.ylabel('probability')
    #ax.set_title(t)
    plt.tight_layout()

# %%
Piezo_activation = pd.DataFrame(pd.read_csv("../data_files/Piezo_Activation.csv"))
#display(static_ap_df) 
graph_df(Piezo_activation,0,4)

# %%
def graph_df10(data_frame:pd.DataFrame,begin_index=0,end_index=None):
    if end_index:
        column_name =list(data_frame.columns )[begin_index:end_index]
    else:
        column_name =list(data_frame.columns )[begin_index:]
    fig, ax = plt.subplots()
    print(column_name)
    x = np.arange(0, len(data_frame), step=1)

    for i in range(len(column_name)):
        label = column_name[i]
        ax.plot(x,data_frame[label],color = color_list[i])
        
    colorlist = zip(column_name,color_list)
    handles = [mpatches.Patch(color=colour, label=column_name) for label, colour in colorlist]
    t = ",".join(column_name)
    plt.legend(handles, column_name, ncol=1, bbox_to_anchor=(1, 1))
    plt.plot()
    plt.xlabel('time (ms)')
    plt.ylabel('current (pA)')
    plt.tight_layout()

# %%
Piezo_activation = pd.DataFrame(pd.read_csv("../data_files/Piezo_Activation.csv"))
#display(static_ap_df) 
graph_df10(Piezo_activation,8,14)

# %%
def graph_df11(data_frame:pd.DataFrame,begin_index=0,end_index=None):
    if end_index:
        column_name =list(data_frame.columns )[begin_index:end_index]
    else:
        column_name =list(data_frame.columns )[begin_index:]
    fig, ax = plt.subplots()
    print(column_name)
    x = np.arange(0, len(data_frame), step=1)

    for i in range(len(column_name)):
        label = column_name[i]
        ax.plot(x,data_frame[label],color = color_list[i])
        
    colorlist = zip(column_name,color_list)
    handles = [mpatches.Patch(color=colour, label=column_name) for label, colour in colorlist]
    t = ",".join(column_name)
    plt.legend(handles, column_name, ncol=1, bbox_to_anchor=(1, 1))
    plt.plot()
    plt.xlabel('time (ms)')
    plt.ylabel('P_total')
    plt.tight_layout()

# %%
Piezo_activation = pd.DataFrame(pd.read_csv("../data_files/Piezo_Activation.csv"))
#display(static_ap_df) 
graph_df11(Piezo_activation,14,23)

# %%
def graph_df(data_frame:pd.DataFrame,begin_index=0,end_index=None):
    if end_index:
        column_name =list(data_frame.columns )[begin_index:end_index]
    else:
        column_name =list(data_frame.columns )[begin_index:]
    fig, ax = plt.subplots()
    print(column_name)
    x = np.arange(0, len(data_frame), step=1)
    

    for i in range(len(column_name)):
        label = column_name[i]
        #ax.scatter(x,test_output[label],color = color_list[i])
        ax.plot(x,data_frame[label],color = color_list[i])
        
    colorlist = zip(column_name,color_list)
    handles = [mpatches.Patch(color=colour, label=column_name) for label, colour in colorlist]
    t = ",".join(column_name)
    plt.legend(handles, column_name, ncol=1, bbox_to_anchor=(1, 1))
    plt.plot()
    plt.xlabel('pressure (mmHg)')
    plt.ylabel('P(open)')
    #ax.set_title(t)
    plt.tight_layout()

# %%
Piezo_activation = pd.DataFrame(pd.read_csv("../data_files/Piezo_Activation.csv"))
#display(static_ap_df) 
graph_df(Piezo_activation,1,2)

# %%
def graph_df2(data_frame:pd.DataFrame,begin_index=0,end_index=None):
    if end_index:
        column_name =list(data_frame.columns )[begin_index:end_index]
    else:
        column_name =list(data_frame.columns )[begin_index:]
    fig, ax = plt.subplots()
    print(column_name)
    x = np.arange(0, len(data_frame), step=1)
    

    for i in range(len(column_name)):
        label = column_name[i]
        #ax.scatter(x,test_output[label],color = color_list[i])
        ax.plot(x,data_frame[label],color = color_list[i])
        
    colorlist = zip(column_name,color_list)
    handles = [mpatches.Patch(color=colour, label=column_name) for label, colour in colorlist]
    t = ",".join(column_name)
    plt.legend(handles, column_name, ncol=1, bbox_to_anchor=(1, 1))
    plt.plot()
    plt.xlabel('substrate stiffness (kPa)')
    plt.ylabel('P(open)')
    #ax.set_title(t)
    plt.tight_layout()

# %%
Piezo_activation = pd.DataFrame(pd.read_csv("../data_files/Piezo_Activation.csv"))
#display(static_ap_df) 
graph_df2(Piezo_activation,2,3)

# %%
def graph_df3(data_frame:pd.DataFrame,begin_index=0,end_index=None):
    if end_index:
        column_name =list(data_frame.columns )[begin_index:end_index]
    else:
        column_name =list(data_frame.columns )[begin_index:]
    fig, ax = plt.subplots()
    print(column_name)
    x = np.arange(0, len(data_frame), step=1)
    

    for i in range(len(column_name)):
        label = column_name[i]
        #ax.scatter(x,test_output[label],color = color_list[i])
        ax.plot(x,data_frame[label],color = color_list[i])
        
    colorlist = zip(column_name,color_list)
    handles = [mpatches.Patch(color=colour, label=column_name) for label, colour in colorlist]
    t = ",".join(column_name)
    plt.legend(handles, column_name, ncol=1, bbox_to_anchor=(1, 1))
    plt.plot()
    plt.xlabel('voltage (mV)')
    plt.ylabel('P(open)')
    #ax.set_title(t)
    plt.tight_layout()

# %%
Piezo_activation = pd.DataFrame(pd.read_csv("../data_files/Piezo_Activation.csv"))
#display(static_ap_df) 
graph_df3(Piezo_activation,3,4)

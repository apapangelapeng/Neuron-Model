# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
color_list =["#3eb991","#6ecadc","#e9a820","#e01563","#edb196","#1f94ac","#ae9a6a","#ccb8a6","#343a44"]
test_output = pd.DataFrame(pd.read_csv("../data_files/reduced_output.csv"))

test_output = test_output.transpose()
test_output= test_output.reset_index(level=0)
display(test_output)
test_output = test_output.dropna()
column_name = list(test_output.iloc[0])
column_name = [ i.strip() for i in column_name]
test_output = test_output.drop(index=0)
test_output.columns = column_name
test_output["V-0.5"] = pd.to_numeric(test_output["V-0.5"])
display(test_output)
# Out:
#             index         0         1         2
# 0           V-0.5     V-0.2      V0.1      V0.4
# 1            -0.5      -0.2       0.1       0.4
# 2           0.075    -0.054     0.141     0.498
# 3        0.118828  0.011457  0.183354  0.620499
# 4        0.162416  0.060576  0.229664  0.765058
# ..            ...       ...       ...       ...
# 498   -0.00712346 -0.015033 -0.000992  0.015763
# 499   -0.00358872   -0.0115  0.002547  0.019328
# 500  -5.17954e-05 -0.007967   0.00609  0.022902
# 501    0.00348813 -0.004433  0.009637  0.026485
# 502  Unnamed: 502       NaN       NaN       NaN
#
# [503 rows x 4 columns]
#         V-0.5     V-0.2      V0.1      V0.4
# 1   -0.500000      -0.2       0.1       0.4
# 2    0.075000    -0.054     0.141     0.498
# 3    0.118828  0.011457  0.183354  0.620499
# 4    0.162416  0.060576  0.229664  0.765058
# 5    0.208766  0.103821  0.282816  0.909128
# ..        ...       ...       ...       ...
# 497 -0.010657 -0.018566 -0.004528  0.012205
# 498 -0.007123 -0.015033 -0.000992  0.015763
# 499 -0.003589   -0.0115  0.002547  0.019328
# 500 -0.000052 -0.007967   0.00609  0.022902
# 501  0.003488 -0.004433  0.009637  0.026485
#
# [501 rows x 4 columns]

# %% [markdown]
# # Data Processing

# %% [markdown]
# # Graph 1
# (first 3)

# %%
first_3 =list(test_output.columns )[:4]
fig, ax = plt.subplots()
x = np.arange(0, 501, step=1)

for i in range(4):
    label = first_3[i]
    #ax.scatter(x,test_output[label],color = color_list[i])
    ax.plot(x,test_output[label],color = color_list[i])
    
colorlist = zip(first_3,color_list)
handles = [mpatches.Patch(color=colour, label=first_3) for label, colour in colorlist]
t = ",".join(first_3)
plt.legend(handles, first_3, ncol=1, bbox_to_anchor=(1, 1))
plt.plot()
ax.set_title(t)
plt.tight_layout()
plt.savefig(f"../graphs/{t}.png")

# %% [markdown]
# # Graph 2

# %%
first_3 = list(test_output.columns)[11:11+2]
fig, ax = plt.subplots()
x = np.arange(0,102, step=1)
print(x.shape)

for i in range(2):
    label = first_3[i]
    #ax.scatter(x,test_output[label],color = color_list[i])
    ax.plot(x,test_output[label],color = color_list[i])
    
colorlist = zip(first_3,color_list)
handles = [mpatches.Patch(color=colour, label=first_3) for label, colour in colorlist]
t = ",".join(first_3)
plt.legend(handles, first_3, ncol=1, bbox_to_anchor=(1, 1))
plt.plot()
ax.set_title(t)
plt.tight_layout()
plt.savefig(f"../graphs/{t}.png")
# Out:
# (102,)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [30], line 7
#       4 print(x.shape)
#       6 for i in range(2):
# ----> 7     label = first_3[i]
#       8     #ax.scatter(x,test_output[label],color = color_list[i])
#       9     ax.plot(x,test_output[label],color = color_list[i])
#
# IndexError: list index out of range

# %% [markdown]
# # Graph 6 Voltages

# %%
voltage = pd.DataFrame(pd.read_csv("../data_files/testV_output.csv"))[:4]

voltage = voltage.transpose().reset_index(level=0)


column =list(voltage.iloc[0])
column = [ i.strip() for i in column]
voltage = voltage.dropna()
voltage = voltage.drop(index=0)
voltage.columns = column
issue_col = list(voltage.columns)[0]

voltage[issue_col] = pd.to_numeric(voltage[issue_col])

#display(voltage) # this shows the voltage 
def graph_v_output(i, voltage):
    first_3 =  [list(voltage.columns)[i]]
    fig, ax = plt.subplots()
    size = len(voltage)
    x = np.arange(0,size/10, step=0.1)

    for i in range(len(first_3)):
        label = first_3[i]
        #ax.scatter(x,test_output[label],color = color_list[i])
        print(label)
        ax.plot(x,voltage[label],color = color_list[i])
        plt.xlabel('time (ms)')
        plt.ylabel('voltage (mV)')

        

    colorlist = zip(first_3,color_list)
    handles = [mpatches.Patch(color=colour, label=first_3) for label, colour in colorlist]
    t = ",".join(first_3)
    ax.set_title(t)
    plt.legend(handles, first_3, ncol=1, bbox_to_anchor=(1, 1))
    plt.plot()
    plt.tight_layout()
    plt.savefig(f"../graphs/{t}.png")

# %%
graph_v_output(0, voltage)
# Out:
# V

# %%
first_3 =  list(voltage.columns)[1:]
fig, ax = plt.subplots()
size = len(voltage)
x = np.arange(0,size/10, step=0.1)

for i in range(len(first_3)):
    label = first_3[i]
    ax.plot(x,voltage[label],color = color_list[i])
    plt.xlabel('time (ms)')
    plt.ylabel('current (uA)')
    

colorlist = zip(first_3,color_list)
handles = [mpatches.Patch(color=colour, label=first_3) for label, colour in colorlist]
t = ",".join(first_3)
ax.set_title(t)
plt.legend(handles, first_3, ncol=1, bbox_to_anchor=(1, 1))
plt.plot()
plt.tight_layout()
plt.savefig(f"../graphs/{t}.png")

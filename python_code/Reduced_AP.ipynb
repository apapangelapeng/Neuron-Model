# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
color_list =["#3eb991","#6ecadc","#e9a820","#e01563","#edb196","#1f94ac","#ae9a6a","#ccb8a6","#343a44"]

# %% [markdown]
# # Graphing definition

# %%
def graph_df(data_frame:pd.DataFrame,begin_index=0,end_index=None):
    if end_index:
        column_name =list(data_frame.columns )[begin_index:end_index]
    else:
        column_name =list(data_frame.columns )[begin_index:]
    fig, ax = plt.subplots()
    x = np.arange(0, len(data_frame), step=1)

    for i in range(len(column_name)):
        label = column_name[i]
        #ax.scatter(x,test_output[label],color = color_list[i])
        ax.plot(x,data_frame[label],color = color_list[i])
        
    colorlist = zip(column_name,color_list)
    handles = [mpatches.Patch(color=colour, label=column_name) for label, colour in colorlist]
    t = ",".join(column_name)
    plt.legend(handles, column_name, ncol=1, bbox_to_anchor=(1, 1))
    plt.plot()
    ax.set_title(t)
    plt.tight_layout()

# %% [markdown]
# # Graphing Propogation

# %%
#propogate_ap_df = pd.DataFrame(pd.read_csv("../data_files/propogate_output.csv"))
#display(propogate_ap_df)
#graph_df(propogate_ap_df,1,len(propogate_ap_df))

# %% [markdown]
# # Graphing Reduction

# %%
reduce_df = pd.DataFrame(pd.read_csv("../data_files/reduced_V_output.csv"))
display(reduce_df)
graph_df(reduce_df)##if u want to graph the full graph u have to do this
# Out:
#                 V0
# 0     4.000000e-01
# 1     4.480000e-01
# 2     5.073290e-01
# 3     5.799350e-01
# 4     6.658080e-01
# ...            ...
# 997  -4.716050e-20
# 998  -4.490320e-20
# 999  -4.275380e-20
# 1000 -4.070740e-20
# 1001 -3.875890e-20
#
# [1002 rows x 1 columns]

# %% [markdown]
# # Graphing Nullcline

# %% [markdown]
# # Graphing Diffusion

# %%
reduce_df = pd.DataFrame(pd.read_csv("../data_files/reduced_diffusion_output.csv"))
display(reduce_df)
graph_df(reduce_df)##if u want to graph the full graph u have to do this
# Out:
#        T0         0.448       0.448.1       0.448.2         0.224  \
# 0    T0.9  9.607120e-01  9.607120e-01  9.607120e-01  4.803560e-01
# 1    T1.9  8.958090e-01  8.958090e-01  8.958090e-01  4.479050e-01
# 2    T2.9  8.147240e-01  8.147240e-01  8.147240e-01  4.073620e-01
# 3    T3.9  6.904460e-01  6.904460e-01  6.904460e-01  3.452230e-01
# 4    T4.9  2.218290e-01  2.218290e-01  2.218290e-01  1.109140e-01
# ..    ...           ...           ...           ...           ...
# 95  T95.9 -2.895640e-19 -2.895640e-19 -2.895640e-19 -1.447820e-19
# 96  T96.9 -1.773070e-19 -1.773070e-19 -1.773070e-19 -8.865370e-20
# 97  T97.9 -1.085700e-19 -1.085700e-19 -1.085700e-19 -5.428490e-20
# 98  T98.9 -6.648000e-20 -6.648000e-20 -6.648000e-20 -3.324000e-20
# 99  T99.9 -4.070740e-20 -4.070740e-20 -4.070740e-20 -2.035370e-20
#
#          0.11424     0.0559776     0.0274738     0.0134393    0.00657497  \
# 0   2.449820e-01  1.200410e-01  5.891610e-02  2.881990e-02  1.409970e-02
# 1   2.284310e-01  1.119310e-01  5.493600e-02  2.687290e-02  1.314710e-02
# 2   2.077550e-01  1.018000e-01  4.996340e-02  2.444050e-02  1.195710e-02
# 3   1.760640e-01  8.627130e-02  4.234200e-02  2.071230e-02  1.013320e-02
# 4   5.656630e-02  2.771750e-02  1.360380e-02  6.654530e-03  3.255620e-03
# ..           ...           ...           ...           ...           ...
# 95 -7.383890e-20 -3.618110e-20 -1.775770e-20 -8.686490e-21 -4.249720e-21
# 96 -4.521340e-20 -2.215460e-20 -1.087350e-20 -5.318960e-21 -2.602210e-21
# 97 -2.768530e-20 -1.356580e-20 -6.658100e-21 -3.256930e-21 -1.593400e-21
# 98 -1.695240e-20 -8.306680e-21 -4.076920e-21 -1.994300e-21 -9.756790e-22
# 99 -1.038040e-20 -5.086390e-21 -2.496400e-21 -1.221160e-21 -5.974330e-22
#
#       0.00321578    0.00157284   0.000769258   0.000376235   0.000184012  \
# 0   6.896070e-03  3.372870e-03  1.649630e-03  8.068160e-04  3.946040e-04
# 1   6.430200e-03  3.145010e-03  1.538190e-03  7.523100e-04  3.679460e-04
# 2   5.848160e-03  2.860340e-03  1.398960e-03  6.842140e-04  3.346410e-04
# 3   4.956080e-03  2.424020e-03  1.185560e-03  5.798440e-04  2.835950e-04
# 4   1.592310e-03  7.787970e-04  3.809000e-04  1.862940e-04  9.111410e-05
# ..           ...           ...           ...           ...           ...
# 95 -2.078520e-21 -1.016600e-21 -4.972090e-22 -2.431790e-22 -1.189360e-22
# 96 -1.272730e-21 -6.224920e-22 -3.044530e-22 -1.489050e-22 -7.282750e-23
# 97 -7.793240e-22 -3.811670e-22 -1.864240e-22 -9.117810e-23 -4.459410e-23
# 98 -4.772000e-22 -2.333980e-22 -1.141520e-22 -5.583070e-23 -2.730610e-23
# 99 -2.922010e-22 -1.429160e-22 -6.989840e-23 -3.418650e-23 -1.672020e-23
#
#     Unnamed: 15
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 95          NaN
# 96          NaN
# 97          NaN
# 98          NaN
# 99          NaN
#
# [100 rows x 16 columns]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [25], line 3
#       1 reduce_df = pd.DataFrame(pd.read_csv("../data_files/reduced_diffusion_output.csv"))
#       2 display(reduce_df)
# ----> 3 graph_df(reduce_df)##if u want to graph the full graph u have to do this
#
# Cell In [22], line 12, in graph_df(data_frame, begin_index, end_index)
#      10     label = column_name[i]
#      11     #ax.scatter(x,test_output[label],color = color_list[i])
# ---> 12     ax.plot(x,data_frame[label],color = color_list[i])
#      14 colorlist = zip(column_name,color_list)
#      15 handles = [mpatches.Patch(color=colour, label=column_name) for label, colour in colorlist]
#
# IndexError: list index out of range

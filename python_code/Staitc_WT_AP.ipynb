# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from graph_static import GraphStatic
color_list =["#3eb991","#e9a820","#e01563","#edb196","#6ecadc","#1f94ac","#ae9a6a","#ccb8a6","#343a44"]

# %%
static_ap_df = pd.DataFrame(pd.read_csv("../data_files/static_wt_output.csv"))
#display(static_ap_df)
GraphStatic.graph_df(static_ap_df,0,1)
GraphStatic.graph_df2(static_ap_df,1,len(static_ap_df))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import os
import glob
from graph_static import GraphStatic
color_list =["#3eb991","#6ecadc","#e9a820","#e01563","#edb196","#1f94ac","#ae9a6a","#ccb8a6","#343a44"]

# %%
def graph_df3(data_frame:pd.DataFrame,begin_index=0,end_index=None):
    if end_index:
        column_name =list(data_frame.columns )[begin_index:end_index]
    else:
        column_name =list(data_frame.columns )[begin_index:]
    fig, ax = plt.subplots()
    x = np.arange(0, len(data_frame)/1000, step=1/1000)

    for i in range(len(column_name)):
        label = column_name[i]
        #ax.scatter(x,test_output[label],color = color_list[i])
        ax.plot(x,data_frame[label]-65,color = color_list[i])
        
    colorlist = zip(column_name,color_list)
    handles = [mpatches.Patch(color=colour, label=column_name) for label, colour in colorlist]
    t = ",".join(column_name)
    plt.legend(handles, column_name, ncol=1, bbox_to_anchor=(1, 1))
    plt.plot()
    plt.xlim(35, 100)
    plt.ylim(-80, 50)
    ax.set_xlabel('time (ms)')
    ax.set_ylabel('voltage (mV)')

    ax.set_title("Voltage")
    plt.tight_layout()

# %%
def graph_df5(data_frame:pd.DataFrame,begin_index=0,end_index=None):
    if end_index:
        column_name =list(data_frame.columns )[begin_index:end_index]
    else:
        column_name =list(data_frame.columns )[begin_index:]
    fig, ax = plt.subplots()
    x = np.arange(0, len(data_frame)/1000, step=1/1000)

    for i in range(len(column_name)):
        label = column_name[i]
        #ax.scatter(x,test_output[label],color = color_list[i])
        ax.plot(x,data_frame[label]-65,color = color_list[i])
        
    colorlist = zip(column_name,color_list)
    handles = [mpatches.Patch(color=colour, label=column_name) for label, colour in colorlist]
    t = ",".join(column_name)
    plt.legend(handles, column_name, ncol=1, bbox_to_anchor=(1, 1))
    plt.plot()
    plt.xlim(52, 58)
    plt.ylim(-75, -60)
    ax.set_xlabel('time (ms)')
    ax.set_ylabel('voltage (mV)')

    ax.set_title("Voltage")
    plt.tight_layout()

# %%
def graph_df4(data_frame:pd.DataFrame,begin_index=0,end_index=None):
        color_list =["#3eb991","#e9a820","#e01563","#edb196","#6ecadc","#1f94ac","#ae9a6a","#ccb8a6","#343a44"]
        if end_index:
            column_name =list(data_frame.columns )[begin_index:end_index]
        else:
            column_name =list(data_frame.columns )[begin_index:]
        fig, ax = plt.subplots()
        x = np.arange(0, len(data_frame)/1000, step=1/1000)

        for i in range(len(column_name)):
            label = column_name[i]
            #ax.scatter(x,test_output[label],color = color_list[i])
            ax.plot(x,data_frame[label],color = color_list[i])
            ax.set_xlabel('time (ms)')
            ax.set_ylabel('current (uA)')
            
        colorlist = zip(column_name,color_list)
        handles = [mpatches.Patch(color=colour, label=column_name) for label, colour in colorlist]
        t = ",".join(column_name)
        plt.legend(handles, column_name, ncol=1, bbox_to_anchor=(1, 1))
        plt.plot()
        plt.xlim(35, 100)
        
        ax.set_title("HCN Currents")
        plt.tight_layout()

# %%
def graph_df6(data_frame:pd.DataFrame,begin_index=0,end_index=None):
        color_list =["#3eb991","#e9a820","#e01563","#edb196","#6ecadc","#1f94ac","#ae9a6a","#ccb8a6","#343a44"]
        if end_index:
            column_name =list(data_frame.columns )[begin_index:end_index]
        else:
            column_name =list(data_frame.columns )[begin_index:]
        fig, ax = plt.subplots()
        x = np.arange(0, len(data_frame)/1000, step=1/1000)

        for i in range(len(column_name)):
            label = column_name[i]
            #ax.scatter(x,test_output[label],color = color_list[i])
            ax.plot(x,data_frame[label],color = color_list[i])
            ax.set_xlabel('time (ms)')
            ax.set_ylabel('Na activation')
            
        colorlist = zip(column_name,color_list)
        handles = [mpatches.Patch(color=colour, label=column_name) for label, colour in colorlist]
        t = ",".join(column_name)
        plt.legend(handles, column_name, ncol=1, bbox_to_anchor=(1, 1))
        plt.plot()
        #plt.ylim(-0.5, 0.5)
        
        ax.set_title("Na Channel Actiation")
        plt.tight_layout()

# %%
static_ap_df = pd.DataFrame(pd.read_csv("../data_files/static_vcompare_output.csv"))
#display(static_ap_df)
#GraphStatic.graph_df2(static_ap_df,1,len(static_ap_df))
graph_df3(static_ap_df,0,4)
graph_df5(static_ap_df,0,4)
graph_df4(static_ap_df,4,7)

# %%
graph_df6(static_ap_df,7,9)
